# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
# Forward & 
h = 0.1

# %%
a = 0;b =2;

# %%
y_a = 0

# %%
def f1(y,x):
    return y - x**2

# %%
y_s = [y_a]
x_s = [a]
while True:
    y_s.append(y_s[-1] + h * f1(y_s[-1],x_s[-1]) )
    x_s.append(x_s[-1]+h)
    if x_s[-1] >= b:
        break

# %%
def Forward(a,b,h,f,y_a):
    y_s = [y_a]
    x_s = [a]
    while True:
        y_s.append(y_s[-1] + h * f(y_s[-1],x_s[-1]) )
        x_s.append(x_s[-1]+h)
        if x_s[-1] >= b:
            break
    return x_s ,y_s

# %%
def y1(x):
    return x**2 + 2*x +2 - 2*np.exp(x)

# %%
y1_s = [y1(item ) for item in x_s]

# %%
x_s = Forward(0,2,0.1,f1,0)[0]
plt.plot(x_s,Forward(0,2,0.1,f1,0)[1],label='Forward 1')
plt.plot(x_s,Predictor_corrector(0,2,0.1,f1,0)[1],label='Predictor')
plt.plot(x_s,y1_s,'bo',label = "Anlytical Solution")
plt.grid(True)
plt.savefig("qiestion_1.png")
plt.savefig("qiestion_.png")
plt.show()

# %%
# Compute slope 1 = hf (y (xn ), xn ) at xn.
# 2. Calculate the predicted y p (xn + h) = y (xn ) + 1, hence compute
# 2 = hf (y p (xn + h), xn + h) = h f (y (xn ) + 1, xn + h).
# 3. Calculate the corrected solution y c (xn + h) = y (xn ) + (1 + 2)/2

# %%
def Predictor_corrector(a,b,h,f,y_a):
    y_s = [y_a]
    x_s = [a]
    while True:
        k1 = h * f(y_s[-1],x_s[-1])
        k2 = h * f(y_s[-1]+k1,x_s[-1]+h)
        y_s.append(y_s[-1] + (k1+k2)/2.0 )
        x_s.append(x_s[-1]+h)
        if x_s[-1] >= b:
            break
    return x_s ,y_s

# %%
def f2(y,x):
    return (x+y)**2

def y2(x):
    return np.tan(x+np.pi/4.0) - x

# %%
x_s = Forward(0,np.pi/5.0,0.1,f1,1)[0]
y2_s = [y2(item) for item in x_s]
plt.plot(x_s,Forward(0,np.pi/5.0,0.1,f2,1)[1],label='Forward 1')
plt.plot(x_s,Predictor_corrector(0,np.pi/5.0,0.1,f2,1)[1],color='green',label='Predictor')
plt.plot(x_s,y2_s,'bo',label = "Anlytical Solution")
plt.legend()
plt.show()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...
